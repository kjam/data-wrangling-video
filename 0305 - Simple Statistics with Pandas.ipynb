# %%
import pandas as pd

# %%
eu_loans = pd.read_csv('data/eu_revolving_loans.csv', header=[1,2,3], index_col=0, skiprows=1, na_values=['-'])

# %%
eu_loans.describe()
# Out:
#                           Austria              Belgium               Cyprus  \
# Collection:     End of period (E)    End of period (E)    End of period (E)
# Period\Unit: [Percent per annum ] [Percent per annum ] [Percent per annum ]
# count                  194.000000           142.000000           159.000000
# mean                     6.660000            10.143028             7.226038
# std                      1.555478             1.316609             0.493942
# min                      3.990000             7.670000             6.130000
# 25%                      5.317500             9.150000             6.840000
# 50%                      6.855000            10.160000             7.250000
# 75%                      7.920000            11.220000             7.685000
# max                      9.120000            12.630000             8.020000
#
#                           Germany              Estonia                Spain  \
# ...

# %%
eu_loans.corr()
# Out:
#                                                                                                               Austria  \
# Collection:                                                                                         End of period (E)
# Period\Unit:                                                                                     [Percent per annum ]
#                                  Collection:                                Period\Unit:
# Austria                          End of period (E)                          [Percent per annum ]             1.000000
# Belgium                          End of period (E)                          [Percent per annum ]             0.933296
# Cyprus                           End of period (E)                          [Percent per annum ]            -0.158893
# Germany                          End of period (E)                          [Percent per annum ]             0.767335
# ...

# %%
eu_loan_corr = eu_loans.corr()

# %%
eu_loan_corr[(eu_loan_corr.abs() > .5) & (eu_loan_corr < 1)].dropna(thresh=3)
# Out:
#                                                                                                               Austria  \
# Collection:                                                                                         End of period (E)
# Period\Unit:                                                                                     [Percent per annum ]
#                                  Collection:                                Period\Unit:
# Austria                          End of period (E)                          [Percent per annum ]                  NaN
# Belgium                          End of period (E)                          [Percent per annum ]             0.933296
# Germany                          End of period (E)                          [Percent per annum ]             0.767335
# Estonia                          End of period (E)                          [Percent per annum ]            -0.779483
# ...

# %%
eu_loans.cov()
# Out:
#                                                                                                               Austria  \
# Collection:                                                                                         End of period (E)
# Period\Unit:                                                                                     [Percent per annum ]
#                                  Collection:                                Period\Unit:
# Austria                          End of period (E)                          [Percent per annum ]             2.419511
# Belgium                          End of period (E)                          [Percent per annum ]             2.117914
# Cyprus                           End of period (E)                          [Percent per annum ]            -0.103836
# Germany                          End of period (E)                          [Percent per annum ]             0.933779
# ...

# %%
eu_loans.cov().min()
# Out:
#                                   Collection:                                 Period\Unit:
# Austria                           End of period (E)                           [Percent per annum ]   -4.537638
# Belgium                           End of period (E)                           [Percent per annum ]   -4.010365
# Cyprus                            End of period (E)                           [Percent per annum ]   -0.971472
# Germany                           End of period (E)                           [Percent per annum ]   -2.631286
# Estonia                           End of period (E)                           [Percent per annum ]   -8.625996
# Spain                             End of period (E)                           [Percent per annum ]   -4.452756
# Finland                           End of period (E)                           [Percent per annum ]   -6.187331
# France                            End of period (E)                           [Percent per annum ]   -6.400211
# ...

# %%
eu_loans.cov().max()
# Out:
#                                   Collection:                                 Period\Unit:
# Austria                           End of period (E)                           [Percent per annum ]     4.183789
# Belgium                           End of period (E)                           [Percent per annum ]     3.744800
# Cyprus                            End of period (E)                           [Percent per annum ]     0.469122
# Germany                           End of period (E)                           [Percent per annum ]     1.557338
# Estonia                           End of period (E)                           [Percent per annum ]    20.045624
# Spain                             End of period (E)                           [Percent per annum ]     3.054069
# Finland                           End of period (E)                           [Percent per annum ]     4.427495
# ...

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
eu_loans.columns = eu_loans.columns.droplevel(1)

# %%
eu_loans.columns = eu_loans.columns.droplevel(1)

# %%
eu_loans
# Out:
#          Austria  Belgium  Cyprus  Germany  Estonia  Spain  Finland  France  \
# 2016Feb     4.20     8.09    6.13     8.85    16.38  11.03     6.41    6.00
# 2016Jan     4.17     8.05    6.13     8.83    16.41  10.85     6.44    6.10
# 2015Dec     3.99     8.21    6.16     8.69    16.32  10.49     6.40    5.86
# 2015Nov     4.09     8.20    6.15     8.82    16.37  10.73     6.49    6.18
# 2015Oct     4.10     8.40    6.16     8.89    16.42  10.86     6.52    6.15
# 2015Sep     4.32     8.58    6.17     8.95    16.44  10.87     6.52    6.41
# 2015Aug     4.28     8.27    6.36     8.91    16.40  10.81     6.47    6.39
# 2015Jul     4.07     8.23    6.38     8.90    16.37  10.74     6.44    6.25
# 2015Jun     4.29     8.17    6.42     9.01    16.36  10.83     6.47    6.57
# 2015May     4.32     8.12    6.46     8.99    16.33  11.07     6.49    6.72
# 2015Apr     4.21     8.24    6.40     9.10    16.31  11.09     6.67    6.58
# ...

# %%
plt = eu_loans[['Latvia', 'Estonia', 'Greece (GR)', 'Ireland', 'Euro area (changing composition)']].plot()

# %%
eu_loans[['Latvia', 'Estonia', 'Greece (GR)', 'Ireland', 'Euro area (changing composition)']].plot(legend=False)

# %%
eu_loans.index
# Out:
# Index([u'2016Feb', u'2016Jan', u'2015Dec', u'2015Nov', u'2015Oct', u'2015Sep',
#        u'2015Aug', u'2015Jul', u'2015Jun', u'2015May',
#        ...
#        u'2000Oct', u'2000Sep', u'2000Aug', u'2000Jul', u'2000Jun', u'2000May',
#        u'2000Apr', u'2000Mar', u'2000Feb', u'2000Jan'],
#       dtype='object', length=194)

# %%
eu_loans.index = eu_loans.index.map(lambda x: datetime.datetime.strptime(x, '%Y%b').date())

# %%
eu_loans[['Latvia', 'Estonia', 'Greece (GR)', 'Ireland', 'Euro area (changing composition)']].plot(legend=False)

# %%
eu_loans[['Latvia', 'Estonia', 'Greece (GR)', 'Ireland', 'Euro area (changing composition)']].plot()

# %%
eu_loans['Latvia'].loc[eu_loans.index > datetime.date(2013,9,1)]
# Out:
# 2016-02-01    21.58
# 2016-01-01    21.51
# 2015-12-01    21.59
# 2015-11-01    21.67
# 2015-10-01    21.74
# 2015-09-01    21.75
# 2015-08-01    21.80
# 2015-07-01    21.82
# 2015-06-01    21.92
# 2015-05-01    21.81
# 2015-04-01    21.86
# 2015-03-01    21.56
# 2015-02-01    21.55
# 2015-01-01    21.61
# 2014-12-01    21.45
# 2014-11-01    21.11
# 2014-10-01    21.12
# 2014-09-01    21.37
# 2014-08-01    21.36
# 2014-07-01    21.38
# 2014-06-01    21.39
# 2014-05-01    21.43
# 2014-04-01    21.35
# 2014-03-01    21.30
# 2014-02-01    21.38
# 2014-01-01    21.66
# 2013-12-01     8.56
# 2013-11-01     8.62
# 2013-10-01     8.78
# Name: Latvia, dtype: float64
