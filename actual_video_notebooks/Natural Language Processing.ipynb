# %%
import nltk

# %%
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> book
#     Downloading collection u'book'
#        |
#        | Downloading package abc to /Users/kjam/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package brown to /Users/kjam/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package chat80 to /Users/kjam/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package cmudict to /Users/kjam/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package conll2000 to /Users/kjam/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /Users/kjam/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package dependency_treebank to
#        |     /Users/kjam/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package genesis to /Users/kjam/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /Users/kjam/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /Users/kjam/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /Users/kjam/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package movie_reviews to /Users/kjam/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package nps_chat to /Users/kjam/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package names to /Users/kjam/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package ppattach to /Users/kjam/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package reuters to /Users/kjam/nltk_data...
#        | Downloading package senseval to /Users/kjam/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package state_union to /Users/kjam/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /Users/kjam/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package swadesh to /Users/kjam/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package timit to /Users/kjam/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package treebank to /Users/kjam/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package toolbox to /Users/kjam/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package udhr to /Users/kjam/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /Users/kjam/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to
#        |     /Users/kjam/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package webtext to /Users/kjam/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /Users/kjam/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /Users/kjam/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /Users/kjam/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /Users/kjam/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package maxent_ne_chunker to
#        |     /Users/kjam/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package universal_tagset to
#        |     /Users/kjam/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package punkt to /Users/kjam/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /Users/kjam/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package city_database to /Users/kjam/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package tagsets to /Users/kjam/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package panlex_swadesh to
#        |     /Users/kjam/nltk_data...
#        | Downloading package averaged_perceptron_tagger to
#        |     /Users/kjam/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        |
#      Done downloading collection book
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# [u'i',
#  u'me',
#  u'my',
#  u'myself',
#  u'we',
#  u'our',
#  u'ours',
#  u'ourselves',
#  u'you',
#  u'your',
#  u'yours',
#  u'yourself',
#  u'yourselves',
#  u'he',
#  u'him',
#  u'his',
#  u'himself',
#  u'she',
#  u'her',
#  u'hers',
#  u'herself',
#  u'it',
#  u'its',
#  u'itself',
#  u'they',
#  u'them',
#  u'their',
#  u'theirs',
#  u'themselves',
#  u'what',
#  u'which',
#  u'who',
#  u'whom',
#  u'this',
#  u'that',
#  u'these',
#  u'those',
#  u'am',
#  u'is',
#  u'are',
#  u'was',
#  u'were',
#  u'be',
#  u'been',
#  u'being',
#  u'have',
#  u'has',
#  u'had',
#  u'having',
#  u'do',
#  u'does',
#  u'did',
#  u'doing',
#  u'a',
#  u'an',
#  u'the',
#  u'and',
#  u'but',
#  u'if',
#  u'or',
#  u'because',
#  u'as',
#  u'until',
#  u'while',
#  u'of',
#  u'at',
#  u'by',
#  u'for',
#  u'with',
#  u'about',
#  u'against',
#  u'between',
#  u'into',
#  u'through',
#  u'during',
#  u'before',
#  u'after',
#  u'above',
#  u'below',
#  u'to',
#  u'from',
#  u'up',
#  u'down',
#  u'in',
#  u'out',
#  u'on',
#  u'off',
#  u'over',
#  u'under',
#  u'again',
#  u'further',
#  u'then',
#  u'once',
#  u'here',
#  u'there',
#  u'when',
#  u'where',
#  u'why',
#  u'how',
#  u'all',
#  u'any',
#  u'both',
#  u'each',
#  u'few',
#  u'more',
#  u'most',
#  u'other',
#  u'some',
#  u'such',
#  u'no',
#  u'nor',
#  u'not',
#  u'only',
#  u'own',
#  u'same',
#  u'so',
#  u'than',
#  u'too',
#  u'very',
#  u's',
#  u't',
#  u'can',
#  u'will',
#  u'just',
#  u'don',
#  u'should',
#  u'now',
#  u'd',
#  u'll',
#  u'm',
#  u'o',
#  u're',
#  u've',
#  u'y',
#  u'ain',
#  u'aren',
#  u'couldn',
#  u'didn',
#  u'doesn',
#  u'hadn',
#  u'hasn',
#  u'haven',
#  u'isn',
#  u'ma',
#  u'mightn',
#  u'mustn',
#  u'needn',
#  u'shan',
#  u'shouldn',
#  u'wasn',
#  u'weren',
#  u'won',
#  u'wouldn']

# %%
from nltk.corpus import brown

# %%
brown.sents(categories=['news', 'editorial'])
# Out:
# [[u'The', u'Fulton', u'County', u'Grand', u'Jury', u'said', u'Friday', u'an', u'investigation', u'of', u"Atlanta's", u'recent', u'primary', u'election', u'produced', u'``', u'no', u'evidence', u"''", u'that', u'any', u'irregularities', u'took', u'place', u'.'], [u'The', u'jury', u'further', u'said', u'in', u'term-end', u'presentments', u'that', u'the', u'City', u'Executive', u'Committee', u',', u'which', u'had', u'over-all', u'charge', u'of', u'the', u'election', u',', u'``', u'deserves', u'the', u'praise', u'and', u'thanks', u'of', u'the', u'City', u'of', u'Atlanta', u"''", u'for', u'the', u'manner', u'in', u'which', u'the', u'election', u'was', u'conducted', u'.'], ...]

# %%
words = [word for word in brown.words(categories=['news', 'editorial'])
        if word not in stopwords.words('english')]

# %%
from collections import Counter

# %%
counter = Counter(words)

# %%
counter
# Out:
# Counter({u'four': 83,
#          u'woods': 4,
#          u'hanging': 2,
#          u'Until': 9,
#          u'aggression': 2,
#          u'Foundation': 3,
#          u'Spectators': 1,
#          u'$25-a-plate': 1,
#          u'all-county': 1,
#          u'Belgians': 20,
#          u'mutinies': 1,
#          u'Western': 23,
#          u'immature': 2,
#          u'Duhagon': 1,
#          u'sinking': 1,
#          u'1,119': 1,
#          u'co-operation': 3,
#          u'Famed': 1,
#          u'stipulate': 1,
#          u'Charitable': 1,
#          u'appropriation': 2,
#          u'yellow': 5,
#          u'fur': 1,
#          u'Heights': 2,
#          u'bringing': 3,
#          u'JNR': 1,
#          u'disturb': 1,
#          u'Loen': 1,
#          u'Less': 3,
#          u'wooden': 1,
#          u'Loeb': 1,
#          u'Does': 15,
#          u'deferments': 1,
#          u'Paul': 9,
#          u'shows': 11,
#          u'commented': 8,
#          u'Convair': 1,
#          u'inevitably': 4,
#          u'271': 1,
#          u'273': 1,
#          u'Pampa': 2,
#          u'DiVarco': 1,
#          u'errors': 10,
#          u'Initially': 1,
#          u'cooking': 1,
#          u'Hamilton': 2,
#          u'designing': 3,
#          u'College': 26,
#          u'payoff': 1,
#          u'succumb': 1,
#          u'Munoz': 1,
#          u'perforations': 1,
#          u'Doe': 1,
#          u'cult': 3,
#          u'affiliated': 2,
#          u'Footnotes': 1,
#          u'Stephanie': 2,
#          u'doldrums': 1,
#          u'cyclical': 1,
#          u'kids': 8,
#          u'elaborate': 3,
#          u'climbed': 2,
#          u'controversy': 6,
#          u'Walters': 1,
#          u'Isles': 1,
#          u'rebel': 5,
#          u'criticism': 5,
#          u'golden': 5,
#          u'Harvey': 7,
#          u"Sandburg's": 1,
#          u'Three': 5,
#          u'replace': 8,
#          u'beneficiaries': 1,
#          u'unearned': 1,
#          u'opponents': 3,
#          u'Ronald': 2,
#          u'Callan': 1,
#          u'Vernor': 1,
#          u'cents': 4,
#          u'Vernon': 4,
#          u'symphony': 1,
#          u'music': 14,
#          u'therefore': 14,
#          u'strike': 16,
#          u'Recent': 2,
#          u'females': 1,
#          u'populations': 1,
#          u'high-wage': 1,
#          u'Rule': 2,
#          u'smelts': 1,
#          u'Hardshell': 1,
#          u'circumstances': 6,
#          u'intake': 1,
#          u'locked': 2,
#          u'homemakers': 1,
#          u'plunged': 1,
#          u'Professors': 2,
#          u'Beebe': 1,
#          u'Travelers': 1,
#          u'revenues': 13,
#          u'example': 32,
#          u'Le': 1,
#          u'La': 8,
#          u'mid-continent': 1,
#          u'currency': 1,
#          u'caution': 1,
#          u'want': 28,
#          u'counseling': 4,
#          u'honest': 5,
#          u'Easier': 1,
#          u'absolute': 3,
#          u'well-armed': 1,
#          u'wracked': 1,
#          u'travel': 7,
#          u'feature': 5,
#          u'cutback': 1,
#          u"He'll": 3,
#          u'cadence': 1,
#          u'Feelers': 1,
#          u'L.': 27,
#          u'Players': 1,
#          u'modest': 13,
#          u'sentencing': 1,
#          u'types': 7,
#          u'down-payments': 1,
#          u'romped': 1,
#          u'season': 49,
#          u'Fifty-ninth': 1,
#          u'baggage': 2,
#          u'18th': 4,
#          u'leisurely': 1,
#          u'Willy': 3,
#          u'welcomed': 4,
#          u'Housing': 5,
#          u"Rogues'": 1,
#          u'Dussa': 1,
#          u'Toll': 1,
#          u'Ludwig': 3,
#          u'Commies': 1,
#          u'welcomes': 1,
#          u'His': 55,
#          u'Hit': 1,
#          u'fit': 5,
#          u'heretofore': 2,
#          u"Gardner's": 4,
#          u'secede': 1,
#          u'survivors': 2,
#          u'Barber': 5,
#          u'Palsy': 1,
#          u'easier': 4,
#          u"Griffin's": 1,
#          u'slate': 1,
#          u'vouchers': 1,
#          u'effects': 13,
#          u'schools': 61,
#          u'man-made': 1,
#          u'sixteen': 1,
#          u'undeveloped': 1,
#          u'glutted': 1,
#          u'scholar': 5,
#          u'Pitney-Bowes': 1,
#          u'loyalties': 1,
#          u'4-year-old': 1,
#          u"employers'": 1,
#          u'Authenticated': 1,
#          u'reputedly': 1,
#          u'series': 39,
#          u'finger-paint': 1,
#          u"NATO's": 1,
#          u'3-to-o': 1,
#          u'substantially': 5,
#          u'worn-out': 1,
#          u'ring': 7,
#          u'drove': 4,
#          u'ten-concert': 1,
#          u'encourage': 6,
#          u'adapt': 1,
#          u'Super': 1,
#          u'foundation': 1,
#          u'inhabitants': 2,
#          u'Word': 2,
#          u'Extension': 1,
#          u'Today': 4,
#          u'Work': 1,
#          u'threatened': 8,
#          u'3-to-3': 1,
#          u'$550': 1,
#          u"Gulf's": 1,
#          u'crowned': 1,
#          u'estimate': 9,
#          u'enormous': 3,
#          u'birdie': 4,
#          u"California's": 2,
#          u'shipped': 1,
#          u'disturbed': 1,
#          u'speedy': 1,
#          u'coeds': 1,
#          u'1970s': 1,
#          u'reserving': 1,
#          u'repealed': 1,
#          u'caught': 10,
#          u'speeds': 1,
#          u'bowl': 1,
#          u'hearsay': 1,
#          u"Hammarskjold's": 4,
#          u'Due': 1,
#          u'channels': 2,
#          u'Tshombe-Gizenga-Goa-Ghana': 1,
#          u'clarity': 1,
#          u'basketball': 5,
#          u'service': 60,
#          u'needed': 39,
#          u'master': 8,
#          u'Russo-American': 1,
#          u'unplowed': 1,
#          u'mid-June': 1,
#          u'advisement': 2,
#          u'Greenberg': 2,
#          u'defaulted': 1,
#          u'showed': 8,
#          u'miniatures': 1,
#          u'tree': 1,
#          u'idly': 1,
#          u'project': 32,
#          u'idle': 4,
#          u'skimmed': 1,
#          u'feeling': 14,
#          u'willingness': 2,
#          u'Chicago': 37,
#          u'Woodyard': 1,
#          u'Mullenax': 2,
#          u'spectrum': 1,
#          u'Abraham': 1,
#          u"Lanin's": 1,
#          u'dozen': 9,
#          u'Then': 35,
#          u'wholesome': 1,
#          u'push-ups': 1,
#          u'bleachers': 2,
#          u'Myron': 1,
#          u'recommended': 10,
#          u'amusing': 1,
#          u'They': 98,
#          u'Ask': 1,
#          u'grips': 3,
#          u'Missionary': 1,
#          u'concedes': 1,
#          u'unmindful': 1,
#          u'vexing': 1,
#          u'debonair': 1,
#          u'mouth': 4,
#          u'conceded': 3,
#          u'Galveston': 2,
#          u'dummy': 2,
#          u'camp': 4,
#          u'Schwada': 1,
#          u'Journal-Bulletin': 1,
#          u'prevention': 2,
#          u'detriment': 1,
#          u'mating': 1,
#          u'purged': 1,
#          u'came': 62,
#          u'Zanzibar': 1,
#          u'saying': 13,
#          u'Symonds': 1,
#          u'U-2': 1,
#          u'insects': 1,
#          u'meetings': 5,
#          u'padded': 1,
#          u'participate': 3,
#          u'falsehoods': 2,
#          u'tempted': 2,
#          u'lessons': 2,
#          u'peck': 1,
#          u'clicked': 1,
#          u'Extend': 1,
#          u'headline': 3,
#          u'Tiao': 1,
#          u'roadhouse': 1,
#          u'rich': 9,
#          u'rice': 1,
#          u"Berlin's": 4,
#          u'plate': 5,
#          u'D.C.': 4,
#          u'Nevertheless': 4,
#          u'denounce': 2,
#          u'foremost': 1,
#          u'pocket': 1,
#          u'altogether': 2,
#          u"Ruth's": 7,
#          u'societies': 2,
#          u'Senators': 5,
#          u'autistic': 13,
#          u'Rip': 1,
#          u'Rio': 2,
#          u"leader's": 4,
#          u'hasten': 1,
#          u'U-I': 1,
#          u'clarified': 1,
#          u'Bennington': 1,
#          u'recruit': 2,
#          u'pads': 1,
#          u'Brevard': 5,
#          u'resigned': 6,
#          u'pricking': 1,
#          u'lots': 9,
#          u'Heinkel': 2,
#          u'rings': 2,
#          u"'20's": 1,
#          u'injuries': 4,
#          u'224-170': 1,
#          u'pressures': 5,
#          u"book's": 1,
#          u'Lockies': 2,
#          u'discipline': 1,
#          u'redistricting': 1,
#          u'nationwide': 3,
#          u'nature': 15,
#          u'punted': 1,
#          u'authorizing': 2,
#          u'extent': 5,
#          u'Bronx': 5,
#          u'Quemoy': 1,
#          u'tyranny': 2,
#          u'planner': 1,
#          u'country': 56,
#          u'Blessed': 1,
#          u'planned': 13,
#          u'logic': 1,
#          u'argue': 3,
#          u'eradicate': 1,
#          u'rehash': 1,
#          u'Apartment': 1,
#          u'liberal-conservative': 1,
#          u'troublesome': 1,
#          u'month-long': 1,
#          u'blonde': 1,
#          u'grazing': 1,
#          u'relearns': 1,
#          u'reconsideration': 2,
#          u'Sitting': 1,
#          u'union': 28,
#          u'subside': 1,
#          u'.': 6511,
#          u'Nischwitz': 3,
#          u'much': 103,
#          u'stadium': 3,
#          u'saute': 1,
#          u'privilege': 4,
#          u'one-week-old': 1,
#          u'dots': 1,
#          u'retrospect': 1,
#          u'Tokyo': 1,
#          u'worker': 2,
#          u'allotting': 1,
#          u'1,212,000': 1,
#          u'doubts': 2,
#          u'worked': 21,
#          u'U.N.-chartered': 1,
#          u'Ben-Gurion': 1,
#          u'employ': 3,
#          u'misconstrued': 1,
#          u'1213-15': 1,
#          u'Campbell': 1,
#          u"Gannon's": 1,
#          u'Zurcher': 2,
#          u'Innumerable': 1,
#          u'conditioned': 2,
#          u'taunts': 1,
#          u'eighteen': 3,
#          u'London-based': 1,
#          u'anticipating': 1,
#          u'Gazette': 3,
#          u'Puerto': 2,
#          u'churchmen': 2,
#          u'Phouma': 4,
#          u'damaged': 2,
#          u'Valley': 3,
#          u"Dresbachs'": 1,
#          u'jolting': 1,
#          u'by-gone': 1,
#          u'split': 7,
#          u'big': 55,
#          u'pre-school': 1,
#          u'Budapest': 5,
#          u'Maybe': 4,
#          u'torpedoes': 1,
#          u'photographers': 1,
#          u'supper': 6,
#          u"Stevenses'": 1,
#          u'furlough': 1,
#          u'matters': 4,
#          u'academic': 11,
#          u'corporate': 3,
#          u'veils': 1,
#          u'capitol': 1,
#          u'sleeps': 1,
#          u'Subsequent': 1,
#          u'Thant': 5,
#          u'Bricker': 1,
#          u'previous': 15,
#          u'ham': 2,
#          u'duffer': 1,
#          u'equipment': 33,
#          u'out-of-town': 2,
#          u'Oscar': 3,
#          u'old-fashioned': 3,
#          u'Odell': 1,
#          u'Leonard': 6,
#          u'Mohammedanism': 1,
#          u'Connecticut': 2,
#          u'innocent': 4,
#          u'hat': 4,
#          u'Bake-Off': 1,
#          u'weeklies': 2,
#          u'municipal': 9,
#          u'survival': 6,
#          u'calypso': 1,
#          u"rocket's": 2,
#          u'knock-down': 1,
#          u'unequivocally': 2,
#          u'indicative': 1,
#          u'Chrysler': 1,
#          u'clustered': 1,
#          u"Glimco's": 1,
#          u'desire': 13,
#          u'psychological': 5,
#          u'Mongi': 1,
#          u'festivities': 4,
#          u'Aristotle': 2,
#          u'grotesquely': 2,
#          u'Pentagon': 6,
#          u"Louis's": 2,
#          u'attorney': 17,
#          u'crowd': 11,
#          u'$1,000,000,000': 1,
#          u'creed': 4,
#          u'Expressways': 1,
#          u'crown': 3,
#          u'culpas': 1,
#          u'captive': 2,
#          u'3,325': 1,
#          u'Between': 1,
#          u'52nd': 1,
#          u'Syrians': 1,
#          u'enemies': 4,
#          u'bottom': 3,
#          u'inhuman': 1,
#          u'p.m.': 40,
#          u'contributing': 2,
#          u'Celebration': 1,
#          u'Instant': 1,
#          u'Calls': 2,
#          u'Valedictorian': 1,
#          u'brigades': 1,
#          u'yoke': 1,
#          u'defensive': 8,
#          u'losing': 9,
#          u'memorable': 2,
#          u'caskets': 1,
#          u'shaken': 3,
#          u'benches': 2,
#          u'globetrotter': 1,
#          u'officeholders': 1,
#          u'stoked': 1,
#          u'raised': 17,
#          u'Blacks': 1,
#          u'facility': 1,
#          u'honeymoon': 4,
#          u'son': 27,
#          u'undermining': 1,
#          u'Aaron': 1,
#          u'one-fourth': 2,
#          u'raiser': 1,
#          u'raises': 3,
#          u'sow': 1,
#          u'wrap': 1,
#          u'fabric': 1,
#          u'waits': 1,
#          u'support': 46,
#          u'constantly': 4,
#          u"boy's": 2,
#          u'greatness': 1,
#          u'resulted': 9,
#          u'launching': 1,
#          u'$200': 1,
#          u'manmade': 1,
#          u'bridgework': 1,
#          u'safeguard': 1,
#          u'incinerator': 1,
#          u'duel': 3,
#          u"else's": 4,
#          u'extremity': 1,
#          u'inside': 11,
#          u'strongest': 5,
#          u'devices': 1,
#          u'County': 46,
#          u'Productions': 1,
#          u'unanimous': 2,
#          u'Hungary-Suez': 1,
#          u'smashed': 1,
#          u'Weatherford': 2,
#          u'Stallard': 1,
#          u'examples': 5,
#          u'150': 3,
#          u'154': 3,
#          u'steady': 3,
#          u'Trooper': 1,
#          u"''": 1084,
#          u'Pittsboro': 1,
#          u'negotiations': 16,
#          u'Francisco': 16,
#          u'eventual': 3,
#          u'Track': 1,
#          u'Possible': 1,
#          u'crowns': 1,
#          u'Possibly': 1,
#          u'role': 10,
#          u'Mays': 10,
#          u'Tract': 2,
#          u'entomologist': 1,
#          u'roll': 5,
#          u'intend': 4,
#          u'models': 3,
#          u'intent': 2,
#          u'smelling': 1,
#          u'Gardens': 1,
#          u'Charley': 4,
#          u'fastened': 1,
#          u'glass': 4,
#          u'Charles': 26,
#          u'Madeira': 1,
#          u'conferred': 1,
#          u'overturned': 1,
#          u'gown': 6,
#          u'chain': 3,
#          u'theaters': 6,
#          u'645-acre': 1,
#          u'Wabash': 1,
#          u'chair': 2,
#          u'93': 2,
#          u'Beyeler': 2,
#          u'ballet': 7,
#          u'92': 2,
#          u'8861': 1,
#          u'900-student': 1,
#          u'sweat-suits': 1,
#          u'Bahi': 1,
#          u'Widow': 1,
#          u'verbally': 2,
#          u'tenacious': 1,
#          u'spate': 1,
#          u'choice': 27,
#          u'Lyle': 1,
#          u'embark': 2,
#          u'stays': 1,
#          u'southpaw': 5,
#          u'exact': 1,
#          u'minute': 3,
#          u'Kai-shek': 1,
#          u'Tau': 1,
#          u'Tax': 5,
#          u'leave': 14,
#          u'settle': 2,
#          u'speculation': 1,
#          u'spiritual': 2,
#          u'budget-altering': 1,
#          u'$80,738': 2,
#          u'trails': 1,
#          u'M.': 26,
#          u'sign': 15,
#          u'3505o': 1,
#          u'reaffirmed': 1,
#          u'ogled': 1,
#          u'Associations': 1,
#          u'Adamson': 1,
#          u'jeopardy': 1,
#          u'celebrated': 3,
#          u'locker': 3,
#          u'melt': 1,
#          u'Landau': 1,
#          u'300': 6,
#          u'looking': 12,
#          u'Loper': 3,
#          u'ground': 15,
#          u'boost': 9,
#          u'Lopez': 1,
#          u'Me': 4,
#          u'drafted': 2,
#          u'jury': 44,
#          u'Mi': 1,
#          u'understanding': 11,
#          u'address': 14,
#          u'$80': 1,
#          u'My': 15,
#          u'momentous': 3,
#          u'Webb': 1,
#          u'passengers': 9,
#          u'hurtling': 1,
#          u'Memorials': 1,
#          u'brilliant': 4,
#          u'Displayed': 1,
#          u'accomplished': 9,
#          u'12-month': 1,
#          u'influx': 2,
#          u'tasks': 3,
#          u'Hagner': 1,
#          u'Thornton': 1,
#          u"Leavitt's": 1,
#          u'Enough': 2,
#          u'redevelopers': 1,
#          u'Davidson': 1,
#          u'opposes': 2,
#          u'August': 14,
#          u'working': 28,
#          u'Sarasota': 1,
#          u'angry': 4,
#          u'opposed': 13,
#          u'Inmates': 2,
#          u'citywide': 1,
#          u'scope': 1,
#          u'liberalizing': 1,
#          u'theoretical': 1,
#          u'Those': 9,
#          u"Nam's": 1,
#          u'Klaus': 1,
#          u'Mortar': 1,
#          u'approving': 1,
#          u'Jimmy': 5,
#          u'everywhere': 1,
#          u'virtue': 2,
#          u'Achaeans': 1,
#          u'scratches': 3,
#          u'Opelika': 1,
#          u'riders': 2,
#          u'Telli': 1,
#          u'Saga': 1,
#          u'originally': 5,
#          u'Mikoyan': 1,
#          u'parimutuels': 1,
#          u'Lois': 2,
#          u'Laotian': 4,
#          u'stature': 4,
#          u'following': 21,
#          u'Newsweek': 1,
#          u'unoriginals': 2,
#          u'admired': 1,
#          u'locks': 1,
#          u'Symphony': 6,
#          u'graduation': 1,
#          u'unveiled': 2,
#          u'allowed': 12,
#          u'week-end': 2,
#          u'stole': 6,
#          u'piled': 1,
#          u'Broglio': 2,
#          u'mid-September': 1,
#          u'Reuther': 1,
#          u'Skinner': 1,
#          u'Knauer': 2,
#          u'undertook': 1,
#          u'encampment': 1,
#          u'provincial': 1,
#          u'23d': 4,
#          u'wardens': 2,
#          u'fueled': 1,
#          u'Bizerte': 3,
#          u'improving': 6,
#          u'Softness': 1,
#          u'38': 3,
#          u'revealed': 4,
#          u'temperate': 1,
#          u'golfers': 3,
#          u'natural': 18,
#          u'conscious': 2,
#          u'consequently': 2,
#          u'ordinarily': 1,
#          u'skirmish': 1,
#          u'wolves': 1,
#          u'misplaced': 1,
#          u'pulled': 4,
#          u'se': 1,
#          u'Centredale': 1,
#          u'augurs': 1,
#          u'Bowie': 1,
#          u'Wyoming': 1,
#          u'years': 165,
#          u'professors': 2,
#          u'episodes': 2,
#          u'Trustees': 2,
#          u'omitting': 1,
#          u'Cromwell': 2,
#          u'tendency': 3,
#          u'tore': 1,
#          u'constituted': 4,
#          u'avid': 1,
#          u'torn': 3,
#          u'troubles': 9,
#          u'Agencies': 1,
#          u'April-June': 1,
#          u'suspicion': 3,
#          u'revulsion': 1,
#          u'foreign-aid': 1,
#          u'suspension': 2,
#          u'troubled': 3,
#          u'Buck': 1,
#          u'Asilomar': 1,
#          u'recipients': 2,
#          u'civilian': 2,
#          u'Kemm': 1,
#          u'courageously': 2,
#          u'nation': 23,
#          u'Gordon': 5,
#          u'Bucs': 1,
#          u'shouted': 2,
#          u'establishing': 3,
#          u'Bubenik': 1,
#          u'Stanley': 4,
#          u'quarter': 6,
#          u'quartet': 2,
#          u'Communists': 23,
#          u'square': 5,
#          u'bursting': 1,
#          u"Cotten's": 1,
#          u'crushing': 1,
#          u'Khrushchevs': 1,
#          u'sponsor': 6,
#          u'entering': 8,
#          u'prudently': 1,
#          u'assessors': 1,
#          u'Michigan': 4,
#          u'Nightclubs': 1,
#          u'squared': 5,
#          u'astray': 1,
#          u'798': 1,
#          u'seriously': 7,
#          u'investigation': 10,
#          u'Article': 2,
#          u'Bouvier': 1,
#          u'recordings': 1,
#          u'lucrative': 1,
#          u'Either': 2,
#          u'grandma': 1,
#          u'Westfield': 4,
#          u'Meyers': 1,
#          u'patronage': 4,
#          u'vocalization': 1,
#          u'wrong': 17,
#          u'initiate': 1,
#          u'aboard': 3,
#          u'Owens': 1,
#          u'emotion': 1,
#          u'saving': 7,
#          u'spoken': 4,
#          u'Royal': 6,
#          u'reprisal': 1,
#          u'one': 334,
#          u'open': 45,
#          u'city': 89,
#          u'Monday': 55,
#          u'Patrolman': 5,
#          u'triple-crown': 1,
#          u'Hmpf': 1,
#          u'36-year-old': 1,
#          u'physically': 4,
#          u'stuffed': 1,
#          u'oversimplified': 1,
#          u'Goodbody': 2,
#          u'Parkhouse': 5,
#          u'slashed': 2,
#          u'specialists': 2,
#          u'surged': 1,
#          u'Seven': 1,
#          u'impractical': 1,
#          u'depressed': 4,
#          u'favors': 1,
#          u'folly': 2,
#          u'Stickney': 4,
#          u'non-stop': 1,
#          u'crossroads': 1,
#          u'so-so': 2,
#          u'Hubert': 2,
#          u'dutifully': 1,
#          u'addressing': 1,
#          u'illness': 6,
#          u'sumptuous': 2,
#          u'Suggest': 1,
#          u'turned': 21,
#          u'locations': 1,
#          u'jewels': 1,
#          u'Field': 10,
#          u'buried': 4,
#          u'borough': 1,
#          u'politicos': 1,
#          u'Idaho': 2,
#          u'Simmonsville': 1,
#          u'instructed': 3,
#          u'indignities': 1,
#          u'intends': 3,
#          u"Pope's": 1,
#          u'Half': 1,
#          u'coincide': 1,
#          u'Hall': 12,
#          u'Zeising': 1,
#          u'Stephenson': 2,
#          u'opposite': 2,
#          u'buffer': 2,
#          u'two-run': 2,
#          u'suspects': 2,
#          u'buffet': 3,
#          u'Allison': 1,
#          u'printed': 4,
#          u'hoped': 13,
#          u'creditable': 1,
#          u'Auditorium': 3,
#          u'Abide': 1,
#          u'lawn': 1,
#          u'Lands': 1,
#          u'average': 24,
#          u'drive': 23,
#          u'Kenilworth': 1,
#          u'Chef': 1,
#          u'jitters': 2,
#          u'Chen': 3,
#          u'Decisions': 1,
#          u'fascinated': 1,
#          u'Substitute': 1,
#          u'laws': 35,
#          u'restriction': 1,
#          u'imagines': 1,
#          u'merit': 4,
#          u'bright': 6,
#          u"'50's": 1,
#          u'Roland': 1,
#          u'inconsistent': 2,
#          u"tourist's": 1,
#          u'aggressive': 3,
#          u'imagined': 1,
#          u'ensembles': 1,
#          u'transact': 1,
#          u'Mary': 18,
#          u'Berlin': 59,
#          u'liberation': 3,
#          u'Leadership': 1,
#          u'dreamed': 2,
#          u'concurrence': 1,
#          u'Bianco': 1,
#          u'presentments': 1,
#          u'suitcases': 1,
#          u'2705': 1,
#          u'assistant': 11,
#          u'freezing': 1,
#          u'balconies': 1,
#          u'battalions': 1,
#          u'Magazine': 1,
#          u'mechanization': 2,
#          u'awaiting': 1,
#          u'Signal': 2,
#          u'Having': 4,
#          u"Government's": 2,
#          u'resource': 2,
#          u'Thereafter': 1,
#          u'uncover': 2,
#          u'Trichieri': 1,
#          u'snapback': 1,
#          u'vision': 1,
#          u'orchids': 1,
#          u'enthralled': 1,
#          u"Prentice's": 1,
#          u'Patricia': 7,
#          u'impressions': 1,
#          u'hastened': 2,
#          u'aroused': 4,
#          u'intoxicating': 1,
#          u'Kan.': 2,
#          u'refresher': 1,
#          u'That': 45,
#          u'alarming': 1,
#          u'sites': 4,
#          u'sponsorship': 2,
#          u'outclassed': 1,
#          u'commando-trained': 1,
#          u'enjoys': 3,
#          u'Peck': 2,
#          u'vertical': 1,
#          u'Harbor': 6,
#          u'screen': 8,
#          u'undistinguished': 1,
#          u'concentrate': 3,
#          u"Gladden's": 2,
#          u"Hodges'": 2,
#          u'McCauley': 2,
#          u"Raphael's": 1,
#          u'oust': 3,
#          u'many': 123,
#          u'expended': 2,
#          u'grooming': 1,
#          u"can't": 26,
#          u'allowance': 3,
#          u'yearly': 4,
#          u'$12,192,865': 1,
#          u'Kaganovich': 1,
#          u'Leavitt': 6,
#          u'Maroy': 1,
#          u'well-prepared': 1,
#          u'Carnegey': 2,
#          u'moans': 1,
#          u'home-bound': 1,
#          u'Riverside': 2,
#          u'Horton': 1,
#          u'considers': 2,
#          u'Tech.': 2,
#          u'go-go-go': 1,
#          u'west': 2,
#          u'recaptured': 1,
#          u'concede': 2,
#          u'collided': 1,
#          u'motives': 1,
#          u'$8.50': 1,
#          u'wants': 18,
#          u'10-hour': 1,
#          u'enable': 4,
#          u'gist': 1,
#          u'Accardo': 1,
#          u'formed': 6,
#          u'readings': 1,
#          u'Districts': 1,
#          u'turtleneck': 2,
#          u'Analysts': 1,
#          u'offshore': 2,
#          u'Davenport': 2,
#          u'former': 39,
#          u'Adjusted': 1,
#          u'co-ordination': 1,
#          u'polls': 5,
#          u'rock-like': 1,
#          u'single': 31,
#          u'Cooch': 2,
#          u'policies': 14,
#          u'squeezed': 3,
#          u'situation': 32,
#          u'spotlight': 2,
#          u'all-round': 1,
#          u'over-stitched': 1,
#          u'engaged': 9,
#          u'bumper': 1,
#          u'pinks': 1,
#          u'technology': 3,
#          u'expenditures': 3,
#          u'missiles': 4,
#          u'$15.5': 1,
#          u"A's": 4,
#          u'Nashville': 4,
#          u'Profili': 1,
#          u'Apocrypha': 1,
#          u'denying': 2,
#          u"veterans'": 1,
#          u'Objects': 1,
#          u'3-game': 1,
#          u'lovers': 2,
#          u'reformatory': 2,
#          u'Kika': 1,
#          u'Whipple': 1,
#          u'managements': 2,
#          u'edged': 1,
#          u'sickness': 1,
#          u'Geraldine': 1,
#          u'downtrodden': 1,
#          u'structurally': 1,
#          u'much-copied': 1,
#          u'edges': 1,
#          u'barber': 1,
#          u'extern': 1,
#          u'Vroman': 1,
#          u'booster': 1,
#          u'Appropriately': 1,
#          u'Manor': 1,
#          u'60,000': 3,
#          u'reiterating': 1,
#          u'May': 32,
#          u'peculiarities': 1,
#          u'parlayed': 1,
#          u'Milwaukee': 4,
#          u'Port': 4,
#          u'NAB': 1,
#          u'I.M.F.': 1,
#          u'steamed': 2,
#          u'cocoon': 2,
#          u'rest': 19,
#          u'Conservative': 1,
#          u'interrupt': 1,
#          u'city-owned': 1,
#          u'exceptions': 3,
#          u'jarred': 1,
#          u'esprit': 3,
#          u'grounder': 1,
#          u'overthrow': 3,
#          u'ebullient': 1,
#          u'aspects': 6,
#          u'around': 50,
#          ...})

# %%
counter.most_common(15)
# Out:
# [(u',', 7954),
#  (u'.', 6511),
#  (u'The', 1259),
#  (u'``', 1128),
#  (u"''", 1084),
#  (u';', 510),
#  (u'--', 492),
#  (u'said', 454),
#  (u'would', 424),
#  (u'?', 384),
#  (u'I', 380),
#  (u'one', 334),
#  (u':', 303),
#  (u'He', 287),
#  (u'Mr.', 280)]

# %%
import numpy as np

# %%
np.mean(counter.values())
# Out:
# 5.5960268427780147

# %%
np.median(counter.values())
# Out:
# 1.0
