# %%
import pandas as pd

# %%
eu_loans = pd.read_csv('data/eu_revolving_loans.csv', header=[1,2,3],
                      skiprows=1, index_col=0, na_values=['-'])

# %%
eu_loans.head()
# Out:
#                           Austria              Belgium               Cyprus  \
# Collection:     End of period (E)    End of period (E)    End of period (E)
# Period\Unit: [Percent per annum ] [Percent per annum ] [Percent per annum ]
# 2016Feb                      4.20                 8.09                 6.13
# 2016Jan                      4.17                 8.05                 6.13
# 2015Dec                      3.99                 8.21                 6.16
# 2015Nov                      4.09                 8.20                 6.15
# 2015Oct                      4.10                 8.40                 6.16
#
#                           Germany              Estonia                Spain  \
# Collection:     End of period (E)    End of period (E)    End of period (E)
# Period\Unit: [Percent per annum ] [Percent per annum ] [Percent per annum ]
# 2016Feb                      8.85                16.38                11.03
# ...

# %%
eu_loans.columns = eu_loans.columns.droplevel(1)

# %%
eu_loans.head()
# Out:
#          Austria  Belgium  Cyprus  Germany  Estonia  Spain  Finland  France  \
# 2016Feb     4.20     8.09    6.13     8.85    16.38  11.03     6.41    6.00
# 2016Jan     4.17     8.05    6.13     8.83    16.41  10.85     6.44    6.10
# 2015Dec     3.99     8.21    6.16     8.69    16.32  10.49     6.40    5.86
# 2015Nov     4.09     8.20    6.15     8.82    16.37  10.73     6.49    6.18
# 2015Oct     4.10     8.40    6.16     8.89    16.42  10.86     6.52    6.15
#
#          Greece (GR)  Ireland  Italy  Lithuania  Luxembourg  Latvia  Malta  \
# 2016Feb         8.18    10.40   6.07       9.60        7.24   21.58   6.79
# 2016Jan         8.19     9.91   6.07       9.58        7.10   21.51   6.82
# 2015Dec         8.22    10.37   5.91       9.45        6.96   21.59   6.84
# 2015Nov         8.30     9.11   6.12       9.53        6.88   21.67   6.78
# 2015Oct         8.34     9.29   6.11       9.40        7.08   21.74   6.78
#
#          Netherlands  Portugal  Slovenia  Slovakia  \
# ...

# %%
eu_loans.describe()
# Out:
#           Austria     Belgium      Cyprus    Germany     Estonia       Spain  \
# count  194.000000  142.000000  159.000000  194.00000  156.000000  194.000000
# mean     6.660000   10.143028    7.226038   10.46799   11.182051   11.848763
# std      1.555478    1.316609    0.493942    0.78234    4.477234    1.453811
# min      3.990000    7.670000    6.130000    8.69000    5.940000    8.070000
# 25%      5.317500    9.150000    6.840000   10.12750    7.182500   10.730000
# 50%      6.855000   10.160000    7.250000   10.40000    8.370000   12.425000
# 75%      7.920000   11.220000    7.685000   10.96000   16.372500   13.020000
# max      9.120000   12.630000    8.020000   12.01000   16.900000   14.090000
#
#           Finland      France  Greece (GR)     Ireland       Italy  \
# count  194.000000  194.000000   194.000000  194.000000  194.000000
# mean     8.899742    9.957835    13.086443   11.723763    8.090722
# std      1.853112    1.749429     2.871678    2.178378    1.094160
# ...

# %%
eu_loans.corr()
# Out:
#                                    Austria   Belgium    Cyprus   Germany  \
# Austria                           1.000000  0.933296 -0.158893  0.767335
# Belgium                           0.933296  1.000000  0.091032  0.840900
# Cyprus                           -0.158893  0.091032  1.000000 -0.026293
# Germany                           0.767335  0.840900 -0.026293  1.000000
# Estonia                          -0.779483 -0.816134  0.210236 -0.713350
# Spain                             0.812410  0.767005 -0.460870  0.662287
# Finland                           0.903886  0.878510 -0.285169  0.878585
# France                            0.935643  0.934225 -0.022965  0.848756
# Greece (GR)                       0.936635  0.863154 -0.057134  0.693189
# Ireland                           0.878040  0.885750 -0.222016  0.808686
# Italy                             0.928940  0.904793 -0.042734  0.737979
# Lithuania                         0.346137  0.196706 -0.741061  0.211564
# ...

# %%
eu_loan_corr = eu_loans.corr()

# %%
eu_loan_corr[(eu_loan_corr.abs() > .5) & 
             (eu_loan_corr < 1)].dropna(thresh=4)
# Out:
#                                    Austria   Belgium  Cyprus   Germany  \
# Austria                                NaN  0.933296     NaN  0.767335
# Belgium                           0.933296       NaN     NaN  0.840900
# Germany                           0.767335  0.840900     NaN       NaN
# Estonia                          -0.779483 -0.816134     NaN -0.713350
# Spain                             0.812410  0.767005     NaN  0.662287
# Finland                           0.903886  0.878510     NaN  0.878585
# France                            0.935643  0.934225     NaN  0.848756
# Greece (GR)                       0.936635  0.863154     NaN  0.693189
# Ireland                           0.878040  0.885750     NaN  0.808686
# Italy                             0.928940  0.904793     NaN  0.737979
# Luxembourg                       -0.643426 -0.724829     NaN -0.629488
# Latvia                           -0.589684 -0.668038     NaN -0.574756
# ...

# %%
eu_loans.cov()
# Out:
#                                    Austria   Belgium    Cyprus   Germany  \
# Austria                           2.419511  2.117914 -0.103836  0.933779
# Belgium                           2.117914  1.733458  0.049440  1.002935
# Cyprus                           -0.103836  0.049440  0.243979 -0.010626
# Germany                           0.933779  1.002935 -0.010626  0.612056
# Estonia                          -4.537638 -3.956379  0.469122 -2.631286
# Spain                             1.837161  1.473269 -0.334862  0.753268
# Finland                           2.605430  2.424479 -0.253941  1.273740
# France                            2.546069  2.411744 -0.019056  1.161649
# Greece (GR)                       4.183789  3.744800 -0.063483  1.557338
# Ireland                           2.975167  2.797553 -0.240351  1.378188
# Italy                             1.581002  1.460503 -0.019208  0.631714
# Lithuania                         0.792435  0.416091 -0.700008  0.352959
# ...

# %%
eu_loans.cov().min()
# Out:
# Austria                            -4.537638
# Belgium                            -4.010365
# Cyprus                             -0.971472
# Germany                            -2.631286
# Estonia                            -8.625996
# Spain                              -4.452756
# Finland                            -6.187331
# France                             -6.400211
# Greece (GR)                        -8.625996
# Ireland                            -8.536770
# Italy                              -2.498610
# Lithuania                          -3.633100
# Luxembourg                         -2.060430
# Latvia                             -8.129378
# Malta                              -0.632835
# Netherlands                        -1.278538
# Portugal                           -5.573948
# Slovenia                           -2.534875
# Slovakia                           -3.155825
# Euro area (changing composition)   -3.540396
# dtype: float64

# %%
eu_loans.cov().max()
# Out:
# Austria                              4.183789
# Belgium                              3.744800
# Cyprus                               0.469122
# Germany                              1.557338
# Estonia                             20.045624
# Spain                                3.054069
# Finland                              4.427495
# France                               4.475095
# Greece (GR)                          8.246534
# Ireland                              5.348316
# Italy                                2.564915
# Lithuania                            3.481155
# Luxembourg                           3.950162
# Latvia                              27.698076
# Malta                                0.356414
# Netherlands                          2.428802
# Portugal                             8.094346
# Slovenia                             3.520594
# Slovakia                             4.406376
# Euro area (changing composition)     2.869212
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
eu_loans[['Latvia', 'Estonia', 'Greece (GR)', 'Ireland']].plot()

# %%
eu_loans.index
# Out:
# Index([u'2016Feb', u'2016Jan', u'2015Dec', u'2015Nov', u'2015Oct', u'2015Sep',
#        u'2015Aug', u'2015Jul', u'2015Jun', u'2015May',
#        ...
#        u'2000Oct', u'2000Sep', u'2000Aug', u'2000Jul', u'2000Jun', u'2000May',
#        u'2000Apr', u'2000Mar', u'2000Feb', u'2000Jan'],
#       dtype='object', length=194)

# %%
eu_loans.index = eu_loans.index.map(
    lambda x: datetime.datetime.strptime(x, '%Y%b').date())

# %%
eu_loans['Latvia'].loc[eu_loans.index > datetime.date(2013, 9, 1)]
# Out:
# 2016-02-01    21.58
# 2016-01-01    21.51
# 2015-12-01    21.59
# 2015-11-01    21.67
# 2015-10-01    21.74
# 2015-09-01    21.75
# 2015-08-01    21.80
# 2015-07-01    21.82
# 2015-06-01    21.92
# 2015-05-01    21.81
# 2015-04-01    21.86
# 2015-03-01    21.56
# 2015-02-01    21.55
# 2015-01-01    21.61
# 2014-12-01    21.45
# 2014-11-01    21.11
# 2014-10-01    21.12
# 2014-09-01    21.37
# 2014-08-01    21.36
# 2014-07-01    21.38
# 2014-06-01    21.39
# 2014-05-01    21.43
# 2014-04-01    21.35
# 2014-03-01    21.30
# 2014-02-01    21.38
# 2014-01-01    21.66
# 2013-12-01     8.56
# 2013-11-01     8.62
# 2013-10-01     8.78
# Name: Latvia, dtype: float64
