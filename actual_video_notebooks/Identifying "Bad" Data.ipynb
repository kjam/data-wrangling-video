# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
weather = pd.read_csv('data/berlin_weather_oldest.csv')

# %%
weather.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# 3 -9999 -9999
# 4 -9999 -9999
#
# [5 rows x 21 columns]

# %%
weather = weather.applymap(lambda x: np.nan if x == -9999 else x)

# %%
weather.head()
# Out:
#              STATION         STATION_NAME      DATE   PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101   46.0   NaN   NaN   NaN
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102  107.0   NaN   NaN  50.0
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103    NaN   NaN   NaN  28.0
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105   13.0   NaN   NaN  39.0
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106    NaN   NaN   NaN   0.0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0 -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4 -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    WT18  WT03
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN
#
# [5 rows x 21 columns]

# %%
weather['DATE'] = weather['DATE'].map(lambda x: datetime.strptime(
        str(x), '%Y%m%d').date())

# %%
weather.notnull().head()
# Out:
#   STATION STATION_NAME  DATE   PRCP   SNWD   SNOW   TMAX  TMIN   WDFG   PGTM  \
# 0    True         True  True   True  False  False  False  True  False  False
# 1    True         True  True   True  False  False   True  True  False  False
# 2    True         True  True  False  False  False   True  True  False  False
# 3    True         True  True   True  False  False   True  True  False  False
# 4    True         True  True  False  False  False   True  True  False  False
#
#    ...     WT09   WT07   WT01   WT06   WT05   WT04   WT16   WT08   WT18   WT03
# 0  ...    False  False  False  False  False  False  False  False  False  False
# 1  ...    False  False  False  False  False  False  False  False  False  False
# 2  ...    False  False  False  False  False  False  False  False  False  False
# 3  ...    False  False  False  False  False  False  False  False  False  False
# 4  ...    False  False  False  False  False  False  False  False  False  False
#
# [5 rows x 21 columns]

# %%
weather.dropna()
# Out:
# Empty DataFrame
# Columns: [STATION, STATION_NAME, DATE, PRCP, SNWD, SNOW, TMAX, TMIN, WDFG, PGTM, WSFG, WT09, WT07, WT01, WT06, WT05, WT04, WT16, WT08, WT18, WT03]
# Index: []
#
# [0 rows x 21 columns]

# %%
weather.dropna(how='all', axis=1)
# Out:
#                   STATION         STATION_NAME        DATE   PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-01   46.0   NaN   NaN
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-02  107.0   NaN   NaN
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-03    NaN   NaN   NaN
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-05   13.0   NaN   NaN
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-06    NaN   NaN   NaN
# 5       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-07   10.0   NaN   NaN
# 6       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-08   13.0   NaN   NaN
# 7       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-09   10.0   NaN   NaN
# 8       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-10    NaN   NaN   NaN
# 9       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-12    NaN   NaN   NaN
# 10      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-13   13.0   NaN   NaN
# 11      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-14   15.0   NaN   NaN
# 12      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-15   13.0   NaN   NaN
# 13      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-16  150.0   NaN   NaN
# 14      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-17   79.0   NaN   NaN
# 15      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-19    NaN   NaN   NaN
# 16      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-20    NaN   NaN   NaN
# 17      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-21   10.0   NaN   NaN
# 18      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-22    NaN   NaN   NaN
# 19      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-23    NaN   NaN   NaN
# 20      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-24   71.0   NaN   NaN
# 21      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-26    NaN   NaN   NaN
# 22      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-27    NaN   NaN   NaN
# 23      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-28    NaN   NaN   NaN
# 24      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-29   56.0   NaN   NaN
# 25      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-30    NaN   NaN   NaN
# 26      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-31   15.0   NaN   NaN
# 27      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-02-01   13.0   NaN   NaN
# 28      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-02-02    NaN   NaN   NaN
# 29      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-02-03   13.0   NaN   NaN
# ...                   ...                  ...         ...    ...   ...   ...
# 117178  GHCND:GMM00010385        SCHONEFELD GM  1992-12-02    0.0   NaN   NaN
# 117179  GHCND:GMM00010385        SCHONEFELD GM  1992-12-03   48.0   NaN   NaN
# 117180  GHCND:GMM00010385        SCHONEFELD GM  1992-12-04    3.0   NaN   NaN
# 117181  GHCND:GMM00010385        SCHONEFELD GM  1992-12-05   48.0   NaN   NaN
# 117182  GHCND:GMM00010385        SCHONEFELD GM  1992-12-06    0.0   NaN   NaN
# 117183  GHCND:GMM00010385        SCHONEFELD GM  1992-12-07    0.0   NaN   NaN
# 117184  GHCND:GMM00010385        SCHONEFELD GM  1992-12-08    0.0   NaN   NaN
# 117185  GHCND:GMM00010385        SCHONEFELD GM  1992-12-09    0.0   NaN   NaN
# 117186  GHCND:GMM00010385        SCHONEFELD GM  1992-12-10    0.0   NaN   NaN
# 117187  GHCND:GMM00010385        SCHONEFELD GM  1992-12-11    0.0   NaN   NaN
# 117188  GHCND:GMM00010385        SCHONEFELD GM  1992-12-12  117.0   NaN   NaN
# 117189  GHCND:GMM00010385        SCHONEFELD GM  1992-12-13   28.0   NaN   NaN
# 117190  GHCND:GMM00010385        SCHONEFELD GM  1992-12-14   66.0   NaN   NaN
# 117191  GHCND:GMM00010385        SCHONEFELD GM  1992-12-15   23.0   NaN   NaN
# 117192  GHCND:GMM00010385        SCHONEFELD GM  1992-12-16    0.0   NaN   NaN
# 117193  GHCND:GMM00010385        SCHONEFELD GM  1992-12-17    0.0   NaN   NaN
# 117194  GHCND:GMM00010385        SCHONEFELD GM  1992-12-18    0.0   NaN   NaN
# 117195  GHCND:GMM00010385        SCHONEFELD GM  1992-12-19    0.0   NaN   NaN
# 117196  GHCND:GMM00010385        SCHONEFELD GM  1992-12-20   66.0   NaN   NaN
# 117197  GHCND:GMM00010385        SCHONEFELD GM  1992-12-21  142.0  10.0   NaN
# 117198  GHCND:GMM00010385        SCHONEFELD GM  1992-12-22    0.0   NaN   NaN
# 117199  GHCND:GMM00010385        SCHONEFELD GM  1992-12-23    0.0   NaN   NaN
# 117200  GHCND:GMM00010385        SCHONEFELD GM  1992-12-24    0.0   NaN   NaN
# 117201  GHCND:GMM00010385        SCHONEFELD GM  1992-12-25    0.0   NaN   NaN
# 117202  GHCND:GMM00010385        SCHONEFELD GM  1992-12-26    0.0   NaN   NaN
# 117203  GHCND:GMM00010385        SCHONEFELD GM  1992-12-27    0.0   NaN   NaN
# 117204  GHCND:GMM00010385        SCHONEFELD GM  1992-12-28    0.0   NaN   NaN
# 117205  GHCND:GMM00010385        SCHONEFELD GM  1992-12-29    0.0   NaN   NaN
# 117206  GHCND:GMM00010385        SCHONEFELD GM  1992-12-30    0.0   NaN   NaN
# 117207  GHCND:GMM00010385        SCHONEFELD GM  1992-12-31    3.0   NaN   NaN
#
#          TMAX   TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  \
# 0         NaN  -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 1        50.0   11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 2        28.0   11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 3        39.0   11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 4         0.0  -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 5         0.0  -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 6        11.0  -28.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 7       -22.0  -61.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 8         0.0  -39.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 9        22.0  -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 10        0.0  -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 11        0.0  -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 12      -11.0  -72.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 13       50.0  -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 14       39.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 15       22.0  -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 16       22.0  -28.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 17        0.0  -28.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 18      -22.0  -61.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 19       61.0  -39.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 20       89.0   11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 21       39.0  -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 22       39.0    0.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 23       39.0    0.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 24       11.0  -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 25        NaN  -11.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 26        0.0  -28.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 27       11.0  -22.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 28      -11.0  -50.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 29      -11.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# ...       ...    ...   ...   ...  ...    ...   ...   ...   ...   ...   ...
# 117178   75.0   17.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117179  120.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117180   72.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117181   77.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117182   34.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117183   30.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117184   33.0   10.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117185    NaN   19.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117186    NaN    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117187   36.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117188   53.0   20.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117189   50.0   14.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117190    NaN   20.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117191   83.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117192   42.0  -20.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117193   34.0  -28.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117194   24.0  -30.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117195   40.0  -10.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117196   34.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117197    NaN    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117198   13.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117199  -20.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117200  -26.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117201    NaN    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117202  -36.0 -120.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117203   10.0  -95.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117204  -16.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117205    NaN    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117206    NaN  -37.0   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
# 117207   -7.0    NaN   NaN   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN
#
#         WT16  WT08  WT18  WT03
# 0        NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN
# 2        NaN   NaN   NaN   NaN
# 3        NaN   NaN   NaN   NaN
# 4        NaN   NaN   NaN   NaN
# 5        NaN   NaN   NaN   NaN
# 6        NaN   NaN   NaN   NaN
# 7        NaN   NaN   NaN   NaN
# 8        NaN   NaN   NaN   NaN
# 9        NaN   NaN   NaN   NaN
# 10       NaN   NaN   NaN   NaN
# 11       NaN   NaN   NaN   NaN
# 12       NaN   NaN   NaN   NaN
# 13       NaN   NaN   NaN   NaN
# 14       NaN   NaN   NaN   NaN
# 15       NaN   NaN   NaN   NaN
# 16       NaN   NaN   NaN   NaN
# 17       NaN   NaN   NaN   NaN
# 18       NaN   NaN   NaN   NaN
# 19       NaN   NaN   NaN   NaN
# 20       NaN   NaN   NaN   NaN
# 21       NaN   NaN   NaN   NaN
# 22       NaN   NaN   NaN   NaN
# 23       NaN   NaN   NaN   NaN
# 24       NaN   NaN   NaN   NaN
# 25       NaN   NaN   NaN   NaN
# 26       NaN   NaN   NaN   NaN
# 27       NaN   NaN   NaN   NaN
# 28       NaN   NaN   NaN   NaN
# 29       NaN   NaN   NaN   NaN
# ...      ...   ...   ...   ...
# 117178   NaN   NaN   NaN   NaN
# 117179   NaN   NaN   NaN   NaN
# 117180   NaN   NaN   NaN   NaN
# 117181   NaN   NaN   NaN   NaN
# 117182   NaN   NaN   NaN   NaN
# 117183   NaN   NaN   NaN   NaN
# 117184   NaN   NaN   NaN   NaN
# 117185   NaN   NaN   NaN   NaN
# 117186   NaN   NaN   NaN   NaN
# 117187   NaN   NaN   NaN   NaN
# 117188   NaN   NaN   NaN   NaN
# 117189   NaN   NaN   NaN   NaN
# 117190   NaN   NaN   NaN   NaN
# 117191   NaN   NaN   NaN   NaN
# 117192   NaN   NaN   NaN   NaN
# 117193   NaN   NaN   NaN   NaN
# 117194   NaN   NaN   NaN   NaN
# 117195   NaN   NaN   NaN   NaN
# 117196   NaN   NaN   NaN   NaN
# 117197   NaN   NaN   NaN   NaN
# 117198   NaN   NaN   NaN   NaN
# 117199   NaN   NaN   NaN   NaN
# 117200   NaN   NaN   NaN   NaN
# 117201   NaN   NaN   NaN   NaN
# 117202   NaN   NaN   NaN   NaN
# 117203   NaN   NaN   NaN   NaN
# 117204   NaN   NaN   NaN   NaN
# 117205   NaN   NaN   NaN   NaN
# 117206   NaN   NaN   NaN   NaN
# 117207   NaN   NaN   NaN   NaN
#
# [117208 rows x 21 columns]

# %%
weather.shape
# Out:
# (117208, 21)

# %%
weather.dropna(thresh=1000, axis=1)
# Out:
#                   STATION         STATION_NAME        DATE   PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-01   46.0   NaN   NaN
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-02  107.0   NaN   NaN
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-03    NaN   NaN   NaN
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-05   13.0   NaN   NaN
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-06    NaN   NaN   NaN
# 5       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-07   10.0   NaN   NaN
# 6       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-08   13.0   NaN   NaN
# 7       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-09   10.0   NaN   NaN
# 8       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-10    NaN   NaN   NaN
# 9       GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-12    NaN   NaN   NaN
# 10      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-13   13.0   NaN   NaN
# 11      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-14   15.0   NaN   NaN
# 12      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-15   13.0   NaN   NaN
# 13      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-16  150.0   NaN   NaN
# 14      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-17   79.0   NaN   NaN
# 15      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-19    NaN   NaN   NaN
# 16      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-20    NaN   NaN   NaN
# 17      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-21   10.0   NaN   NaN
# 18      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-22    NaN   NaN   NaN
# 19      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-23    NaN   NaN   NaN
# 20      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-24   71.0   NaN   NaN
# 21      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-26    NaN   NaN   NaN
# 22      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-27    NaN   NaN   NaN
# 23      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-28    NaN   NaN   NaN
# 24      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-29   56.0   NaN   NaN
# 25      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-30    NaN   NaN   NaN
# 26      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-01-31   15.0   NaN   NaN
# 27      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-02-01   13.0   NaN   NaN
# 28      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-02-02    NaN   NaN   NaN
# 29      GHCND:GME00111445  BERLIN TEMPELHOF GM  1931-02-03   13.0   NaN   NaN
# ...                   ...                  ...         ...    ...   ...   ...
# 117178  GHCND:GMM00010385        SCHONEFELD GM  1992-12-02    0.0   NaN   NaN
# 117179  GHCND:GMM00010385        SCHONEFELD GM  1992-12-03   48.0   NaN   NaN
# 117180  GHCND:GMM00010385        SCHONEFELD GM  1992-12-04    3.0   NaN   NaN
# 117181  GHCND:GMM00010385        SCHONEFELD GM  1992-12-05   48.0   NaN   NaN
# 117182  GHCND:GMM00010385        SCHONEFELD GM  1992-12-06    0.0   NaN   NaN
# 117183  GHCND:GMM00010385        SCHONEFELD GM  1992-12-07    0.0   NaN   NaN
# 117184  GHCND:GMM00010385        SCHONEFELD GM  1992-12-08    0.0   NaN   NaN
# 117185  GHCND:GMM00010385        SCHONEFELD GM  1992-12-09    0.0   NaN   NaN
# 117186  GHCND:GMM00010385        SCHONEFELD GM  1992-12-10    0.0   NaN   NaN
# 117187  GHCND:GMM00010385        SCHONEFELD GM  1992-12-11    0.0   NaN   NaN
# 117188  GHCND:GMM00010385        SCHONEFELD GM  1992-12-12  117.0   NaN   NaN
# 117189  GHCND:GMM00010385        SCHONEFELD GM  1992-12-13   28.0   NaN   NaN
# 117190  GHCND:GMM00010385        SCHONEFELD GM  1992-12-14   66.0   NaN   NaN
# 117191  GHCND:GMM00010385        SCHONEFELD GM  1992-12-15   23.0   NaN   NaN
# 117192  GHCND:GMM00010385        SCHONEFELD GM  1992-12-16    0.0   NaN   NaN
# 117193  GHCND:GMM00010385        SCHONEFELD GM  1992-12-17    0.0   NaN   NaN
# 117194  GHCND:GMM00010385        SCHONEFELD GM  1992-12-18    0.0   NaN   NaN
# 117195  GHCND:GMM00010385        SCHONEFELD GM  1992-12-19    0.0   NaN   NaN
# 117196  GHCND:GMM00010385        SCHONEFELD GM  1992-12-20   66.0   NaN   NaN
# 117197  GHCND:GMM00010385        SCHONEFELD GM  1992-12-21  142.0  10.0   NaN
# 117198  GHCND:GMM00010385        SCHONEFELD GM  1992-12-22    0.0   NaN   NaN
# 117199  GHCND:GMM00010385        SCHONEFELD GM  1992-12-23    0.0   NaN   NaN
# 117200  GHCND:GMM00010385        SCHONEFELD GM  1992-12-24    0.0   NaN   NaN
# 117201  GHCND:GMM00010385        SCHONEFELD GM  1992-12-25    0.0   NaN   NaN
# 117202  GHCND:GMM00010385        SCHONEFELD GM  1992-12-26    0.0   NaN   NaN
# 117203  GHCND:GMM00010385        SCHONEFELD GM  1992-12-27    0.0   NaN   NaN
# 117204  GHCND:GMM00010385        SCHONEFELD GM  1992-12-28    0.0   NaN   NaN
# 117205  GHCND:GMM00010385        SCHONEFELD GM  1992-12-29    0.0   NaN   NaN
# 117206  GHCND:GMM00010385        SCHONEFELD GM  1992-12-30    0.0   NaN   NaN
# 117207  GHCND:GMM00010385        SCHONEFELD GM  1992-12-31    3.0   NaN   NaN
#
#          TMAX   TMIN  WT01  WT16  WT08
# 0         NaN  -11.0   NaN   NaN   NaN
# 1        50.0   11.0   NaN   NaN   NaN
# 2        28.0   11.0   NaN   NaN   NaN
# 3        39.0   11.0   NaN   NaN   NaN
# 4         0.0  -22.0   NaN   NaN   NaN
# 5         0.0  -22.0   NaN   NaN   NaN
# 6        11.0  -28.0   NaN   NaN   NaN
# 7       -22.0  -61.0   NaN   NaN   NaN
# 8         0.0  -39.0   NaN   NaN   NaN
# 9        22.0  -11.0   NaN   NaN   NaN
# 10        0.0  -22.0   NaN   NaN   NaN
# 11        0.0  -22.0   NaN   NaN   NaN
# 12      -11.0  -72.0   NaN   NaN   NaN
# 13       50.0  -11.0   NaN   NaN   NaN
# 14       39.0    NaN   NaN   NaN   NaN
# 15       22.0  -22.0   NaN   NaN   NaN
# 16       22.0  -28.0   NaN   NaN   NaN
# 17        0.0  -28.0   NaN   NaN   NaN
# 18      -22.0  -61.0   NaN   NaN   NaN
# 19       61.0  -39.0   NaN   NaN   NaN
# 20       89.0   11.0   NaN   NaN   NaN
# 21       39.0  -11.0   NaN   NaN   NaN
# 22       39.0    0.0   NaN   NaN   NaN
# 23       39.0    0.0   NaN   NaN   NaN
# 24       11.0  -11.0   NaN   NaN   NaN
# 25        NaN  -11.0   NaN   NaN   NaN
# 26        0.0  -28.0   NaN   NaN   NaN
# 27       11.0  -22.0   NaN   NaN   NaN
# 28      -11.0  -50.0   NaN   NaN   NaN
# 29      -11.0    NaN   NaN   NaN   NaN
# ...       ...    ...   ...   ...   ...
# 117178   75.0   17.0   NaN   NaN   NaN
# 117179  120.0    NaN   NaN   NaN   NaN
# 117180   72.0    NaN   NaN   NaN   NaN
# 117181   77.0    NaN   NaN   NaN   NaN
# 117182   34.0    NaN   NaN   NaN   NaN
# 117183   30.0    NaN   NaN   NaN   NaN
# 117184   33.0   10.0   NaN   NaN   NaN
# 117185    NaN   19.0   NaN   NaN   NaN
# 117186    NaN    NaN   NaN   NaN   NaN
# 117187   36.0    NaN   NaN   NaN   NaN
# 117188   53.0   20.0   NaN   NaN   NaN
# 117189   50.0   14.0   NaN   NaN   NaN
# 117190    NaN   20.0   NaN   NaN   NaN
# 117191   83.0    NaN   NaN   NaN   NaN
# 117192   42.0  -20.0   NaN   NaN   NaN
# 117193   34.0  -28.0   NaN   NaN   NaN
# 117194   24.0  -30.0   NaN   NaN   NaN
# 117195   40.0  -10.0   NaN   NaN   NaN
# 117196   34.0    NaN   NaN   NaN   NaN
# 117197    NaN    NaN   NaN   NaN   NaN
# 117198   13.0    NaN   NaN   NaN   NaN
# 117199  -20.0    NaN   NaN   NaN   NaN
# 117200  -26.0    NaN   NaN   NaN   NaN
# 117201    NaN    NaN   NaN   NaN   NaN
# 117202  -36.0 -120.0   NaN   NaN   NaN
# 117203   10.0  -95.0   NaN   NaN   NaN
# 117204  -16.0    NaN   NaN   NaN   NaN
# 117205    NaN    NaN   NaN   NaN   NaN
# 117206    NaN  -37.0   NaN   NaN   NaN
# 117207   -7.0    NaN   NaN   NaN   NaN
#
# [117208 rows x 11 columns]

# %%
weather['DATE'].dtype
# Out:
# dtype('O')

# %%
weather = weather.set_index(pd.DatetimeIndex(weather['DATE']))

# %%
weather.index.duplicated()
# Out:
# array([False, False, False, ...,  True,  True,  True], dtype=bool)

# %%
weather['STATION_NAME'].value_counts()
# Out:
# POTSDAM GM             36525
# BERLIN DAHLEM GM       36335
# BERLIN TEMPELHOF GM    22874
# BERLIN TEGEL GM        15738
# SCHONEFELD GM           3164
# TEMPELHOF GM            2367
# TEGEL GM                 205
# Name: STATION_NAME, dtype: int64

# %%
weather.index.drop_duplicates().sort_values()
# Out:
# DatetimeIndex(['1900-01-01', '1900-01-02', '1900-01-03', '1900-01-04',
#                '1900-01-05', '1900-01-06', '1900-01-07', '1900-01-08',
#                '1900-01-09', '1900-01-10',
#                ...
#                '1999-12-23', '1999-12-24', '1999-12-25', '1999-12-26',
#                '1999-12-27', '1999-12-28', '1999-12-29', '1999-12-30',
#                '1999-12-31', '2000-01-01'],
#               dtype='datetime64[ns]', length=36525, freq=None)

# %%
weather.groupby('STATION_NAME').resample('D').mean().head()
# Out:
#                              PRCP  SNWD  SNOW  TMAX  TMIN  WDFG  PGTM  WSFG  \
# STATION_NAME
# BERLIN DAHLEM GM 1900-01-01   6.0   NaN   NaN  28.0  -9.0   NaN   NaN   NaN
#                  1900-01-02   2.0   NaN   NaN  29.0   5.0   NaN   NaN   NaN
#                  1900-01-03  43.0   NaN   NaN  69.0  19.0   NaN   NaN   NaN
#                  1900-01-04  15.0   NaN   NaN  75.0  20.0   NaN   NaN   NaN
#                  1900-01-05   0.0   NaN   NaN  50.0  10.0   NaN   NaN   NaN
#
#                              WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# STATION_NAME
# BERLIN DAHLEM GM 1900-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                  1900-01-02   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                  1900-01-03   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                  1900-01-04   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#                  1900-01-05   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                              WT18  WT03
# STATION_NAME
# BERLIN DAHLEM GM 1900-01-01   NaN   NaN
#                  1900-01-02   NaN   NaN
#                  1900-01-03   NaN   NaN
#                  1900-01-04   NaN   NaN
#                  1900-01-05   NaN   NaN
